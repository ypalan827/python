# %%
list=['Machine Learning','Neural Networks','Vision','Robotics','Speech Processings','Natural Language Processing']
def subfieldsofAI():
    print('Subfields of AI are:')
    for name in list:
        print(name)
subfieldsofAI()
# Out:
# Subfields of AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processings
# Natural Language Processing

# %%
def oddeven():
    num=int(input('Enter a number:'))
    if (num%2==1):
        print(num,'is an Odd number')
    else:
        print(num,'is an Even num')
oddeven() 

Enter a number:52452
52452 is an Even num

def eligibility_for_marriage():
    gender=input('Enter gender:')
    age=int(input('Enter age:'))
    if gender=='MALE':
        if(age<21):
            print('Not Eligible')
        else:
            print('Eligible')
    if gender=='FEMALE'  :
        if(age<18):
            print('Not Eligible')
        else:
            print('Eligible')
eligibility_for_marriage()

Enter gender:MALE
Enter age:20
Not Eligible            
​
def percentage():
    sub1=int(input('Subject1='))
    sub2=int(input('Subject2='))
    sub3=int(input('Subject3='))
    sub4=int(input('Subject4='))
    sub5=int(input('Subject5='))
    max=500
    total=sub1+sub2+sub3+sub4+sub5
    print('Total:',total)
    percentage=(total/500)*100
    print('Percentage:',percentage)
percentage()    
    
Subject1=98
Subject2=87
Subject3=95
Subject4=95
Subject5=93
Total: 468
Percentage: 93.60000000000001
    
    
def triangle():
    Height=int(input('Height:'))
    Breadth=int(input('Breadth:'))
    area=(Height*Breadth)/2
    print('Area formula:(Height*Breadth)/2')
    print('Area of Triangle:',area)
    Height1=int(input('Height1:'))
    Height2=int(input('Height2:'))
    Breadth=int(input('Breadth:'))
    perimeter=Height1+Height2+Breadth
    print('Perimeter formula:Height1+Height2+Breadth')
    print('Perimeter of Triangle:',perimeter)
triangle()        
    
Height:32
Breadth:34
Area formula:(Height*Breadth)/2
Area of Triangle: 544.0
Height1:2
Height2:4
Breadth:4
Perimeter formula:Height1+Height2+Breadth
Perimeter of Triangle: 10

​
